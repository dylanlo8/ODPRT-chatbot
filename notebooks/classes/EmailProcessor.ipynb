# %%
# %cd ..
# Out:
# /Users/lishuyao/Documents/NUS/MODS/Y3S2/Capstone

# %%
import os

os.environ["OPENAI_KEY"] = "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"
os.environ["OPENAI_MODEL"] = "gpt-4o-mini"

import numpy as np

# %%
from chatbot.backend.email_processor.email_processor import EmailProcessor

# %%
email_processor = EmailProcessor()

# %%
qa_pairs = email_processor.get_qa_pairs()
# Out:
# Saved attachment: /Users/lishuyao/Documents/NUS/MODS/Y3S2/Capstone/ODPRT-chatbot/processed_docs/emails_with_attachments/General 04-04A/original_attachments
# Saved cleaned email at: /Users/lishuyao/Documents/NUS/MODS/Y3S2/Capstone/ODPRT-chatbot/processed_docs/emails_with_attachments/General 04-04A/cleaned_msg.txt
# Saved attachment: /Users/lishuyao/Documents/NUS/MODS/Y3S2/Capstone/ODPRT-chatbot/processed_docs/emails_with_attachments/General 04-04B/original_attachments
# Saved attachment: /Users/lishuyao/Documents/NUS/MODS/Y3S2/Capstone/ODPRT-chatbot/processed_docs/emails_with_attachments/General 04-04B/original_attachments
# Saved cleaned email at: /Users/lishuyao/Documents/NUS/MODS/Y3S2/Capstone/ODPRT-chatbot/processed_docs/emails_with_attachments/General 04-04B/cleaned_msg.txt
# Saved attachment: /Users/lishuyao/Documents/NUS/MODS/Y3S2/Capstone/ODPRT-chatbot/processed_docs/emails_with_attachments/General 04-04C/original_attachments
# ...

# %%
qa_pairs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 qa_pairs
#
# NameError: name 'qa_pairs' is not defined

# %%
import pickle

with open("data_pkl/email_qa_pairs.pkl", "wb") as file:  # "wb" means write binary
    pickle.dump(qa_pairs, file)

# %%
from chatbot.backend.faq_parser.faq_parser import FAQ_Parser
faq_parser = FAQ_Parser()
faq_qa_pairs = faq_parser.extract_faq()
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[19], line 3
#       1 from chatbot.backend.faq_parser.faq_parser import FAQ_Parser
#       2 faq_parser = FAQ_Parser()
# ----> 3 faq_qa_pairs = faq_parser.extract_faq()
#
# File ~/Documents/NUS/MODS/Y3S2/Capstone/ODPRT-chatbot/chatbot/backend/faq_parser/faq_parser.py:29, in FAQ_Parser.extract_faq(self)
#      27 full_text = []
#      28 for doc in self.directory:
# ---> 29     doc = Document(doc)
#      31     for para in doc.paragraphs:
#      32         full_text.append(para.text)
#
# File ~/miniconda3/envs/odprt/lib/python3.9/site-packages/docx/api.py:27, in Document(docx)
#      20 """Return a |Document| object loaded from `docx`, where `docx` can be either a path
#      21 to a ``.docx`` file (a string) or a file-like object.
#      22
# ...

# %%
len(faq_qa_pairs)
# Out:
# 31826

# %%
for pair in faq_qa_pairs:
    print(pair)
# Out:
# A
# g
# r
# e
# e
# m
# e
# n
# t
#
# T
# y
# p
# e
#
# A
# g
# r
# e
# e
# m
# e
# n
# t
#
# T
# y
# p
# e
#
#
# Q
# u
# e
# s
# t
# i
# o
# n
#
# I
#
# w
# i
# l
# l
#
# b
# e
#
# w
# o
# r
# k
# i
# n
# g
#
# w
# i
# t
# h
#
# a
# n
#
# e
# x
# t
# e
# r
# n
# a
# l
#
# c
# o
# m
# p
# a
# n
# y
#
# o
# n
#
# a
#
# p
# r
# o
# j
# e
# c
# t
# .
#
# W
# h
# o
#
# c
# a
# n
#
# I
#
# c
# o
# n
# t
# a
# c
# t
#
# t
# o
#
# g
# e
# t
#
# m
# o
# r
# e
#
# i
# n
# f
# o
# r
# m
# a
# t
# i
# o
# n
#
# o
# n
#
# t
# h
# e
#
# t
# y
# p
# e
#
# o
# f
#
# a
# g
# r
# e
# e
# m
# e
# n
# t
#
# r
# e
# q
# u
# i
# r
# e
# d
# ?
#
#
# A
# n
# s
# w
# e
# r
#
# I
# s
#
# y
# o
# u
# r
#
# a
# g
# r
# e
# e
# m
# e
# n
# t
#
# r
# e
# s
# e
# a
# r
# c
# h
#
# r
# e
# l
# a
# t
# e
# d
# ?
#
# I
# f
#
# y
# e
# s
# ,
#
# p
# l
# e
# a
# s
# e
#
# r
# e
# f
# e
# r
#
# t
# o
#
# O
# D
# P
# R
# T
#
# -
#
# R
# e
# s
# e
# a
# r
# c
# h
#
# A
# g
# r
# e
# e
# m
# e
# n
# t
# s
#
# f
# o
# r
#
# ...

# %%
from docx import Document

def extract_qa_from_tables(doc_path):
    """
    Extracts question-answer pairs from tables in a Word document (.docx).
    """
    doc = Document(doc_path)
    qa_pairs = []

    for table in doc.tables:  # Iterate through all tables in the document
        for row in table.rows:
            if len(row.cells) >= 2:  # Ensure the row has at least two columns
                question = row.cells[0].text.strip()
                answer = row.cells[1].text.strip()
                
                if question and answer:  # Avoid empty rows
                    qa_pairs.append((question, answer))
    return qa_pairs

def correct_qa_pairing(qa_pairs):
    """
    Cleans and formats extracted question-answer pairs.
    Ensures valid pairing and removes unwanted labels.
    """
    cleaned_pairs = []
    current_question = None

    for entry in qa_pairs:
        key, text = entry  # Key is "Question" or "Answer", text is the actual content

        # If the entry is a question
        if key.lower().startswith("question") or key.lower().startswith("questions"):
            if current_question:  # If there's an existing question without an answer, discard it
                cleaned_pairs.append((current_question, "No answer provided"))
            current_question = text.strip()  # Store the new question
        
        # If the entry is an answer and there's an active question, store the pair
        elif key.lower().startswith("answer") and current_question:
            cleaned_pairs.append((current_question, text.strip()))
            current_question = None  # Reset for next pair

    return [f"question: {q}, answer: {a}" for q, a in cleaned_pairs]

# Load the document and extract Q&A pairs
file_path = "/Users/lishuyao/Documents/NUS/MODS/Y3S2/Capstone/ODPRT-chatbot/docs/IEP FAQ.docx"  # Change to your file path
qa_pairs = extract_qa_from_tables(file_path)

# Process the extracted Q&A pairs into the required format
final_qa_pairs = correct_qa_pairing(qa_pairs)

# Print the formatted Q&A pairs
for qa in final_qa_pairs:
    print(qa)
    print("\n")
# Out:
# question: I will be working with an external company on a project. Who can I contact to get more information on the type of agreement required?, answer: Is your agreement research related? If yes, please refer to ODPRT - Research Agreements for more information on types of agreement.
#
# If your agreement is not research related, please contact the relevant offices below:
# (a) Intellectual Property (IP) matters, IP agreement, Materials Transfer, outgoing Data transfer, NUS IP licences; contact Technology Transfer and Innovation office (TTI) - Contract-Admin@nus.edu.sg
#
# (b) General legal advice, non-research /academic/student related agreements, incoming data transfer (for research or otherwise), in-licensing of data/software/IP, provision of services (non-research), employment agreements; contact Office of Legal Affairs (OLA) – olasec@nus.edu.sg
#
# (c) procurement (for research or non-research services/goods): contact central Procurement Office (CPO) – askcpo@nus.edu.sg.
#
# ...

# %%
with open("data_pkl/faq_qa_pairs.pkl", "wb") as file:  # "wb" means write binary
    pickle.dump(faq_qa_pairs, file)

# %%
import pickle
with open("data_pkl/Agreement Type 01-02B/MOA Work Plan_NUS_NUH_Changi Grant_WH12012024_processed_processed/text_chunks.pkl", "rb") as file:  # "rb" means read binary
    loaded_data = pickle.load(file)

print(loaded_data)
# Out:
# ['\nPage 1\nWORK PLAN FOR THE PROJECT entitled “(insert Project title here)”\n\nThe Parties had, pursuant to the Memorandum of Agreement dated 18" July 2022 (“MOA”),\nagreed to enter into a Work Plan to collaborate on a Project in lieu of the Project Agreement\nrequired under Section 2 of the Singapore Public Sector Master Research Collaboration\nAgreement dated 26 April 2018 (“MRCA’). Pursuant to Clause 2.1 of the MOA, the Project Parties now enter into this Work Plan and\nthis Work Plan, as read together with the MOA and the Project Terms and Conditions as set\nout in the MOA (“Project T&C”) shall be deemed to constitute the Project Agreement\ngoverning the Project. This Work Plan and any counterparts may be executed electronically whether by emailed\nportable document format (PDF) document or other mutually agreeable document format\nand such electronic version shall be treated as an original. Pursuant to the respective sections in the Project T&C, the Project Parties agree as\nfo
# ...

# %%
from chatbot.backend.document_parser.document_parser import DocumentParser

# %%
doc_parser = DocumentParser()

# %%
doc_parser.process_and_save_attachments()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100%|██████████| 1/1 [00:05<00:00,  5.86s/it]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ...
